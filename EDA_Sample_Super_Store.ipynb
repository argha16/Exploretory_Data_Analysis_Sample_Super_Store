# %% [markdown]
# <h2>Exploretory Data Analysis on Sample Superstore by Argha Das</h2>

# %% [markdown]
# <h3>Importing Library</h3>

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# <h3>Loading the Dataset</h3>

# %%
df_store=pd.read_csv("SampleSuperstore.csv",encoding ='latin-1')

# %% [markdown]
# <h2>Data Exploration Process</h2>

# %% [markdown]
# <h3>Print First Five Row</h3>

# %%
df_store.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# <h3>Print Last Five Row</h3>

# %%
df_store.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# <h3>Print Ramdome 10 Rows </h3>

# %%
df_store.sample(10)
# Out:
#            Ship Mode    Segment        Country           City       State  \
# 6978    Second Class   Consumer  United States        Atlanta     Georgia
# 6248  Standard Class   Consumer  United States       Columbus     Indiana
# 9485    Second Class  Corporate  United States        Houston       Texas
# 655   Standard Class   Consumer  United States       Columbus        Ohio
# 1631        Same Day   Consumer  United States      Cleveland        Ohio
# 1609    Second Class   Consumer  United States    Los Angeles  California
# 5993        Same Day  Corporate  United States       Columbus        Ohio
# 4958  Standard Class   Consumer  United States     Carrollton       Texas
# 8207  Standard Class   Consumer  United States  Daytona Beach     Florida
# 2871  Standard Class  Corporate  United States         Tucson     Arizona
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 6978        30318    South  Office Supplies        Paper   48.870         9
# ...

# %% [markdown]
# <h3>Check The Missing Value </h3>

# %%
df_store.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <h3>Finding Total Number of Null Values in This Dataset</h3>

# %%
print("Total Number of Null Values =",df_store.isnull().sum().sum())
# Out:
# Total Number of Null Values = 0

# %% [markdown]
# <h3>Full Summary of The Dataframe</h3>

# %%
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <h3>Statistical Details of Dataset</h3>

# %%
df_store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# <h3>Datatype of Dataset</h3>

# %%
df_store.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# <h3>Find All Coulmn in Dataset</h3>

# %%
df_store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# <h2>Data Cleaning Process</h2>

# %% [markdown]
# <h3>Find and Drop Duplicate Eliment in Dataset</h3>

# %%
#findling duplicate eliments in dataset
df_store.duplicated().sum()
# Out:
# 17

# %%
#dropping duplicate eliments
df_store.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <h3>Find Distinct Observation of the Dataset</h3>

# %%
df_store.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <h3>Find the correlation of dataset</h3>

# %%
df_store.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# <h3>Find the Covarience of Dataset</h3>

# %%
df_store.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %% [markdown]
# <h3>Find the serise which contain unique vaule</h3>

# %%
df_store.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# ...

# %% [markdown]
# <h3>Drop Column from Dataset</h3>

# %%
df_store.drop(columns='Postal Code',axis=1)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <h2>Data Visualization Process</h2>

# %% [markdown]
# <h3>Visualize Bar plot between Category and Subcategory</h3>

# %%
plt.figure(figsize=(18,8))
plt.bar('Sub-Category','Category',data=df_store)
plt.show()

# %% [markdown]
#   <h3>Observation</h3>
#
# <ul>
#     <li>Office Supplies produtes are selling in a highest number</li>
#     <li>Furniture and Technologies products are selling in same amount </li>
#     <li>Office supplies products are in highest demand than any other products</li>
# </ul>

# %% [markdown]
# <h3>Visualize count plot of State</h3>

# %%
df_store['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(16,8))
sns.countplot(x=df_store['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h3>Observation</h3>
# <ul>
#     <li>Highest no of sell came from California</li>
#     <li>lowest number of sell came from Wyoming</li>
#     <li>We need to figure out how to improve sell in Wyoming , West Virginia , North Dakota </li>
#
# </ul>

# %% [markdown]
# <h3>Visualize count plot of Subcategory</h3>

# %%
df_store['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.countplot(x=df_store['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h3>Observation</h3>
# <ul>
#     <li>Highest selling product is Binders</li>
#     <li>lowest Selling product is Copiers</li>
#     <li>We need to figure out how to improve selling of Copiers , Machines , Bookcases</li>
#
# </ul>

# %% [markdown]
# <h3>Countplot of Segment</h3>

# %%
sns.countplot(x=df_store['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# <h3>Observation</h3>
# <ul>
#     <li>Highest number of products are purchased by direct customer</li>
# </ul>

# %% [markdown]
# <h3>Countplot of Region</h3>

# %%
sns.countplot(x=df_store['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# <h3>Observation</h3>
# <ul>
#     <li>West region have highest purcheses by customer</li>
# </ul>

# %% [markdown]
# <h3>Heatmap of Correlative Data</h3>

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(df_store.corr(), annot= True)
plt.show()

# %% [markdown]
# <h3>Heatmap of Covarrience Data</h3>

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(df_store.cov(), annot= True)
plt.show()

# %% [markdown]
# <h3>Barplot between Sub-category and profit</h3>

# %%
plt.figure(figsize=(40,25))
sns.barplot(x=df_store['Sub-Category'] ,y=df_store['Profit'])
plt.show()

# %% [markdown]
# <h3>lineplot between Discount and profit</h3>

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data = df_store, color = 'r', label= 'Discount')
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h3> Visualize Histogram of this dataset</h3>

# %%
df_store.hist(bins=50 ,figsize=(20,15))
plt.show()

# %% [markdown]
# <h3> Visualize Pair plot on Subcategories</h3>

# %%
figsize=(15,10)
sns.pairplot(df_store,hue='Sub-Category')

# %% [markdown]
# <h3>Visualize The Boxplot of Discount</h3>

# %%
fig, axes = plt.subplots(figsize = (10 , 10))

sns.boxplot(df_store['Discount'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount'>

# %% [markdown]
# <h3>Visualize the Scatterplot between Sales and profit</h3>

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(df_store["Sales"] , df_store["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
<plt.show()

# %% [markdown]
# <h3>Visualize the Distribution plot on Sales</h3>

# %%
print(df_store['Sales'].describe())
plt.figure(figsize = (9 , 8))
sns.distplot(df_store['Sales'], color = 'b', bins = 100, hist_kws = {'alpha': 0.4});
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <h3>Grouped or sum the sales ,profit,discount,quantity according to every state of region and also according to sub-categories sales</h3>

# %%
Super_grouped=pd.DataFrame(df_store.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
Super_grouped
# Out:
# C:\Users\ARGHA\AppData\Local\Temp/ipykernel_9436/196679390.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Super_grouped=pd.DataFrame(df_store.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# ...
